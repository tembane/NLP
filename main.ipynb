# %%
from scraper import get_comments
from data_processing import detect_language
from data_processing import comment_len

# %%
df = get_comments(max_result=100, number_of_pages=20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6413 entries, 0 to 6412
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ChannelName  6413 non-null   object
#  1   VideoId      6413 non-null   object
#  2   AuthorId     6413 non-null   object
#  3   Comment      6413 non-null   object
# dtypes: object(4)
# memory usage: 200.5+ KB

# %%
df = detect_language(df)

# %%
df = comment_len(df)

# %%
df.head()
# Out:
#       ChannelName      VideoId                AuthorId  \
# 0  Marilyn Manson  ca07wR75-ko  @michaelmazzarella2176
# 1  Marilyn Manson  K7l3tIsRM7s             @ChozoBrain
# 2  Marilyn Manson  VdV1Zc_PFdg           @Shelley_wald
# 3  Marilyn Manson  C7VXrHLyUQk                @ReLu616
# 4  Marilyn Manson  F9YJS4nTNsM          @peggyrupf2119
#
#                                         Comment Language  WordCount  SentCount
# 0  He is the greatest singer I got is music too       en         10          1
# 1                       Best song on the album.       en          6          1
# 2                             Since 1997 ❤crazy     None          3          1
# 3  Braian, you very close to heart! Thenk\nyou/       en         10          2
# 4         I love his real talk ❤ authentic man!     None          9          1

# %%
from visualization import *

# %%
lang_visual(df, len(df))

# %%
visual_word_count(df, len(df))
# Out:
# /home/tembane/miniconda3/envs/nlp/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
visual_sent_count(df, len(df))
# Out:
# /home/tembane/miniconda3/envs/nlp/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
